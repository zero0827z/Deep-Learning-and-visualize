# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
import tensorflow as tf
print(tf.__version__)

import os
from google.colab import drive 
drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2`. This will be interpreted as: `1.x`.
#
#
# TensorFlow 1.x selected.
# 1.15.2
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# /content/gdrive/My Drive

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
# 印出網路結構
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# 1712/1712 [==============================] - 15s 8ms/step - loss: 0.0068 - val_loss: 0.0023
#
# Epoch 00001: val_loss improved from inf to 0.00228, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0018 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00228 to 0.00195, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0014 - val_loss: 0.0019
#
# Epoch 00003: val_loss improved from 0.00195 to 0.00187, saving model to best_weights.h5
# Epoch 4/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0012 - val_loss: 0.0019
#
# Epoch 00004: val_loss improved from 0.00187 to 0.00185, saving model to best_weights.h5
# Epoch 5/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0011 - val_loss: 0.0018
#
# Epoch 00005: val_loss improved from 0.00185 to 0.00182, saving model to best_weights.h5
# Epoch 6/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.7900e-04 - val_loss: 0.0017
#
# Epoch 00006: val_loss improved from 0.00182 to 0.00172, saving model to best_weights.h5
# Epoch 7/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 8.3423e-04 - val_loss: 0.0016
#
# Epoch 00007: val_loss improved from 0.00172 to 0.00160, saving model to best_weights.h5
# Epoch 8/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 7.3522e-04 - val_loss: 0.0014
#
# Epoch 00008: val_loss improved from 0.00160 to 0.00136, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 6.4001e-04 - val_loss: 0.0013
#
# Epoch 00009: val_loss improved from 0.00136 to 0.00129, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 5.8189e-04 - val_loss: 0.0012
#
# Epoch 00010: val_loss improved from 0.00129 to 0.00119, saving model to best_weights.h5
# Epoch 11/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 5.3194e-04 - val_loss: 0.0011
#
# Epoch 00011: val_loss improved from 0.00119 to 0.00111, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 5.0445e-04 - val_loss: 0.0011
#
# Epoch 00012: val_loss improved from 0.00111 to 0.00111, saving model to best_weights.h5
# Epoch 13/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 4.8059e-04 - val_loss: 0.0011
#
# Epoch 00013: val_loss improved from 0.00111 to 0.00106, saving model to best_weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 4.4517e-04 - val_loss: 0.0010
#
# Epoch 00014: val_loss improved from 0.00106 to 0.00101, saving model to best_weights.h5
# Epoch 15/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 4.3025e-04 - val_loss: 9.9167e-04
#
# Epoch 00015: val_loss improved from 0.00101 to 0.00099, saving model to best_weights.h5
# Epoch 16/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 4.0655e-04 - val_loss: 9.5599e-04
#
# Epoch 00016: val_loss improved from 0.00099 to 0.00096, saving model to best_weights.h5
# Epoch 17/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.7237e-04 - val_loss: 9.0295e-04
#
# Epoch 00017: val_loss improved from 0.00096 to 0.00090, saving model to best_weights.h5
# Epoch 18/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.5490e-04 - val_loss: 8.7469e-04
#
# Epoch 00018: val_loss improved from 0.00090 to 0.00087, saving model to best_weights.h5
# Epoch 19/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.5381e-04 - val_loss: 9.1569e-04
#
# Epoch 00019: val_loss did not improve from 0.00087
# Epoch 20/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.3899e-04 - val_loss: 8.6632e-04
#
# Epoch 00020: val_loss improved from 0.00087 to 0.00087, saving model to best_weights.h5
# Epoch 21/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.2973e-04 - val_loss: 8.3971e-04
#
# Epoch 00021: val_loss improved from 0.00087 to 0.00084, saving model to best_weights.h5
# Epoch 22/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.0809e-04 - val_loss: 8.6480e-04
#
# Epoch 00022: val_loss did not improve from 0.00084
# Epoch 23/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.0950e-04 - val_loss: 8.4337e-04
#
# Epoch 00023: val_loss did not improve from 0.00084
# Epoch 24/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.0347e-04 - val_loss: 8.4452e-04
#
# Epoch 00024: val_loss did not improve from 0.00084
# Epoch 25/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.9578e-04 - val_loss: 8.1688e-04
#
# Epoch 00025: val_loss improved from 0.00084 to 0.00082, saving model to best_weights.h5
# Epoch 26/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.8266e-04 - val_loss: 8.2726e-04
#
# Epoch 00026: val_loss did not improve from 0.00082
# Epoch 27/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.7257e-04 - val_loss: 8.2128e-04
#
# Epoch 00027: val_loss did not improve from 0.00082
# Epoch 28/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.6190e-04 - val_loss: 7.8566e-04
#
# Epoch 00028: val_loss improved from 0.00082 to 0.00079, saving model to best_weights.h5
# Epoch 29/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.5832e-04 - val_loss: 7.7519e-04
#
# Epoch 00029: val_loss improved from 0.00079 to 0.00078, saving model to best_weights.h5
# Epoch 30/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.5471e-04 - val_loss: 7.9596e-04
#
# Epoch 00030: val_loss did not improve from 0.00078
# Epoch 31/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.5031e-04 - val_loss: 7.8474e-04
#
# Epoch 00031: val_loss did not improve from 0.00078
# Epoch 32/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.5070e-04 - val_loss: 8.4260e-04
#
# Epoch 00032: val_loss did not improve from 0.00078
# Epoch 33/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.4362e-04 - val_loss: 7.8409e-04
#
# Epoch 00033: val_loss did not improve from 0.00078
# Epoch 34/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.3662e-04 - val_loss: 7.8148e-04
#
# Epoch 00034: val_loss did not improve from 0.00078
# Epoch 35/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.3361e-04 - val_loss: 7.8269e-04
#
# Epoch 00035: val_loss did not improve from 0.00078
# Epoch 36/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.2980e-04 - val_loss: 8.1937e-04
#
# Epoch 00036: val_loss did not improve from 0.00078
# Epoch 37/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.2909e-04 - val_loss: 8.0138e-04
#
# Epoch 00037: val_loss did not improve from 0.00078
# Epoch 38/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.2200e-04 - val_loss: 7.8610e-04
#
# Epoch 00038: val_loss did not improve from 0.00078
# Epoch 39/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.1599e-04 - val_loss: 7.6355e-04
#
# Epoch 00039: val_loss improved from 0.00078 to 0.00076, saving model to best_weights.h5
# Epoch 40/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.0993e-04 - val_loss: 7.7851e-04
#
# Epoch 00040: val_loss did not improve from 0.00076
# Epoch 41/150
# 1712/1712 [==============================] - 17s 10ms/step - loss: 2.0748e-04 - val_loss: 7.6008e-04
#
# Epoch 00041: val_loss improved from 0.00076 to 0.00076, saving model to best_weights.h5
# Epoch 42/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.1315e-04 - val_loss: 7.6037e-04
#
# Epoch 00042: val_loss did not improve from 0.00076
# Epoch 43/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.0695e-04 - val_loss: 8.0033e-04
#
# Epoch 00043: val_loss did not improve from 0.00076
# Epoch 44/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.9783e-04 - val_loss: 7.7453e-04
#
# Epoch 00044: val_loss did not improve from 0.00076
# Epoch 45/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.9839e-04 - val_loss: 7.8700e-04
#
# Epoch 00045: val_loss did not improve from 0.00076
# Epoch 46/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.9316e-04 - val_loss: 7.8305e-04
#
# Epoch 00046: val_loss did not improve from 0.00076
# Epoch 47/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.9523e-04 - val_loss: 7.6574e-04
#
# Epoch 00047: val_loss did not improve from 0.00076
# Epoch 48/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.9620e-04 - val_loss: 7.9676e-04
#
# Epoch 00048: val_loss did not improve from 0.00076
# Epoch 49/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.8748e-04 - val_loss: 7.3749e-04
#
# Epoch 00049: val_loss improved from 0.00076 to 0.00074, saving model to best_weights.h5
# Epoch 50/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.8751e-04 - val_loss: 7.5978e-04
#
# Epoch 00050: val_loss did not improve from 0.00074
# Epoch 51/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.8408e-04 - val_loss: 7.5465e-04
#
# Epoch 00051: val_loss did not improve from 0.00074
# Epoch 52/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.8211e-04 - val_loss: 7.3452e-04
#
# Epoch 00052: val_loss improved from 0.00074 to 0.00073, saving model to best_weights.h5
# Epoch 53/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.8443e-04 - val_loss: 7.6115e-04
#
# Epoch 00053: val_loss did not improve from 0.00073
# Epoch 54/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.7475e-04 - val_loss: 7.4510e-04
#
# Epoch 00054: val_loss did not improve from 0.00073
# Epoch 55/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.7246e-04 - val_loss: 7.5907e-04
#
# Epoch 00055: val_loss did not improve from 0.00073
# Epoch 56/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.7364e-04 - val_loss: 7.5511e-04
#
# Epoch 00056: val_loss did not improve from 0.00073
# Epoch 57/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.6847e-04 - val_loss: 7.4791e-04
#
# Epoch 00057: val_loss did not improve from 0.00073
# Epoch 58/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.6895e-04 - val_loss: 7.5148e-04
#
# Epoch 00058: val_loss did not improve from 0.00073
# Epoch 59/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.6342e-04 - val_loss: 7.5943e-04
#
# Epoch 00059: val_loss did not improve from 0.00073
# Epoch 60/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.6162e-04 - val_loss: 7.5880e-04
#
# Epoch 00060: val_loss did not improve from 0.00073
# Epoch 61/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.5838e-04 - val_loss: 7.7189e-04
#
# Epoch 00061: val_loss did not improve from 0.00073
# Epoch 62/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.5962e-04 - val_loss: 7.3181e-04
#
# Epoch 00062: val_loss improved from 0.00073 to 0.00073, saving model to best_weights.h5
# Epoch 63/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.6581e-04 - val_loss: 7.4282e-04
#
# Epoch 00063: val_loss did not improve from 0.00073
# Epoch 64/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.5578e-04 - val_loss: 7.5863e-04
#
# Epoch 00064: val_loss did not improve from 0.00073
# Epoch 65/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.5342e-04 - val_loss: 7.7605e-04
#
# Epoch 00065: val_loss did not improve from 0.00073
# Epoch 66/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.5242e-04 - val_loss: 7.3338e-04
#
# Epoch 00066: val_loss did not improve from 0.00073
# Epoch 67/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.5226e-04 - val_loss: 7.4860e-04
#
# Epoch 00067: val_loss did not improve from 0.00073
# Epoch 68/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.5451e-04 - val_loss: 7.4425e-04
#
# Epoch 00068: val_loss did not improve from 0.00073
# Epoch 69/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.5480e-04 - val_loss: 7.7082e-04
#
# Epoch 00069: val_loss did not improve from 0.00073
# Epoch 70/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.5151e-04 - val_loss: 7.6599e-04
#
# Epoch 00070: val_loss did not improve from 0.00073
# Epoch 71/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4610e-04 - val_loss: 7.7062e-04
#
# Epoch 00071: val_loss did not improve from 0.00073
# Epoch 72/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4313e-04 - val_loss: 7.6311e-04
#
# Epoch 00072: val_loss did not improve from 0.00073
# Epoch 73/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4247e-04 - val_loss: 7.7360e-04
#
# Epoch 00073: val_loss did not improve from 0.00073
# Epoch 74/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4579e-04 - val_loss: 7.8738e-04
#
# Epoch 00074: val_loss did not improve from 0.00073
# Epoch 75/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3981e-04 - val_loss: 7.8494e-04
#
# Epoch 00075: val_loss did not improve from 0.00073
# Epoch 76/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3954e-04 - val_loss: 7.6986e-04
#
# Epoch 00076: val_loss did not improve from 0.00073
# Epoch 77/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3843e-04 - val_loss: 8.3956e-04
#
# Epoch 00077: val_loss did not improve from 0.00073
# Epoch 78/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3758e-04 - val_loss: 7.6064e-04
#
# Epoch 00078: val_loss did not improve from 0.00073
# Epoch 79/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3488e-04 - val_loss: 7.7991e-04
#
# Epoch 00079: val_loss did not improve from 0.00073
# Epoch 80/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3805e-04 - val_loss: 7.8468e-04
#
# Epoch 00080: val_loss did not improve from 0.00073
# Epoch 81/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3718e-04 - val_loss: 7.7866e-04
#
# Epoch 00081: val_loss did not improve from 0.00073
# Epoch 82/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2934e-04 - val_loss: 7.6024e-04
#
# Epoch 00082: val_loss did not improve from 0.00073
# Epoch 83/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3224e-04 - val_loss: 7.7224e-04
#
# Epoch 00083: val_loss did not improve from 0.00073
# Epoch 84/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3057e-04 - val_loss: 7.5885e-04
#
# Epoch 00084: val_loss did not improve from 0.00073
# Epoch 85/150
# 1712/1712 [==============================] - 18s 10ms/step - loss: 1.3069e-04 - val_loss: 7.6513e-04
#
# Epoch 00085: val_loss did not improve from 0.00073
# Epoch 86/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3089e-04 - val_loss: 7.5615e-04
#
# Epoch 00086: val_loss did not improve from 0.00073
# Epoch 87/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2984e-04 - val_loss: 7.4145e-04
#
# Epoch 00087: val_loss did not improve from 0.00073
# Epoch 88/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2822e-04 - val_loss: 7.6162e-04
#
# Epoch 00088: val_loss did not improve from 0.00073
# Epoch 89/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2719e-04 - val_loss: 7.9512e-04
#
# Epoch 00089: val_loss did not improve from 0.00073
# Epoch 90/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2642e-04 - val_loss: 7.8919e-04
#
# Epoch 00090: val_loss did not improve from 0.00073
# Epoch 91/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2631e-04 - val_loss: 7.3371e-04
#
# Epoch 00091: val_loss did not improve from 0.00073
# Epoch 92/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2351e-04 - val_loss: 7.5828e-04
#
# Epoch 00092: val_loss did not improve from 0.00073
# Epoch 93/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2635e-04 - val_loss: 7.6801e-04
#
# Epoch 00093: val_loss did not improve from 0.00073
# Epoch 94/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2365e-04 - val_loss: 7.4820e-04
#
# Epoch 00094: val_loss did not improve from 0.00073
# Epoch 95/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1930e-04 - val_loss: 7.6475e-04
#
# Epoch 00095: val_loss did not improve from 0.00073
# Epoch 96/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1935e-04 - val_loss: 7.5016e-04
#
# Epoch 00096: val_loss did not improve from 0.00073
# Epoch 97/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2242e-04 - val_loss: 7.3869e-04
#
# Epoch 00097: val_loss did not improve from 0.00073
# Epoch 98/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1780e-04 - val_loss: 7.8313e-04
#
# Epoch 00098: val_loss did not improve from 0.00073
# Epoch 99/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2225e-04 - val_loss: 7.4350e-04
#
# Epoch 00099: val_loss did not improve from 0.00073
# Epoch 100/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1954e-04 - val_loss: 7.5289e-04
#
# Epoch 00100: val_loss did not improve from 0.00073
# Epoch 101/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1510e-04 - val_loss: 7.3750e-04
#
# Epoch 00101: val_loss did not improve from 0.00073
# Epoch 102/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1420e-04 - val_loss: 7.4058e-04
#
# Epoch 00102: val_loss did not improve from 0.00073
# Epoch 103/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1285e-04 - val_loss: 7.4745e-04
#
# Epoch 00103: val_loss did not improve from 0.00073
# Epoch 104/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1493e-04 - val_loss: 7.5516e-04
#
# Epoch 00104: val_loss did not improve from 0.00073
# Epoch 105/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1443e-04 - val_loss: 7.9260e-04
#
# Epoch 00105: val_loss did not improve from 0.00073
# Epoch 106/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1855e-04 - val_loss: 7.5445e-04
#
# Epoch 00106: val_loss did not improve from 0.00073
# Epoch 107/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1360e-04 - val_loss: 7.7333e-04
#
# Epoch 00107: val_loss did not improve from 0.00073
# Epoch 108/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1159e-04 - val_loss: 7.6464e-04
#
# Epoch 00108: val_loss did not improve from 0.00073
# Epoch 109/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1223e-04 - val_loss: 7.6306e-04
#
# Epoch 00109: val_loss did not improve from 0.00073
# Epoch 110/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0710e-04 - val_loss: 7.3408e-04
#
# Epoch 00110: val_loss did not improve from 0.00073
# Epoch 111/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0611e-04 - val_loss: 7.2523e-04
#
# Epoch 00111: val_loss improved from 0.00073 to 0.00073, saving model to best_weights.h5
# Epoch 112/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0549e-04 - val_loss: 7.6101e-04
#
# Epoch 00112: val_loss did not improve from 0.00073
# Epoch 113/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0205e-04 - val_loss: 7.4869e-04
#
# Epoch 00113: val_loss did not improve from 0.00073
# Epoch 114/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0594e-04 - val_loss: 7.3606e-04
#
# Epoch 00114: val_loss did not improve from 0.00073
# Epoch 115/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0694e-04 - val_loss: 7.3401e-04
#
# Epoch 00115: val_loss did not improve from 0.00073
# Epoch 116/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0289e-04 - val_loss: 7.6070e-04
#
# Epoch 00116: val_loss did not improve from 0.00073
# Epoch 117/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0223e-04 - val_loss: 7.3369e-04
#
# Epoch 00117: val_loss did not improve from 0.00073
# Epoch 118/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0351e-04 - val_loss: 7.2935e-04
#
# Epoch 00118: val_loss did not improve from 0.00073
# Epoch 119/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.9464e-05 - val_loss: 7.5284e-04
#
# Epoch 00119: val_loss did not improve from 0.00073
# Epoch 120/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0465e-04 - val_loss: 7.5867e-04
#
# Epoch 00120: val_loss did not improve from 0.00073
# Epoch 121/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0095e-04 - val_loss: 7.4649e-04
#
# Epoch 00121: val_loss did not improve from 0.00073
# Epoch 122/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0040e-04 - val_loss: 7.3386e-04
#
# Epoch 00122: val_loss did not improve from 0.00073
# Epoch 123/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0129e-04 - val_loss: 7.3713e-04
#
# Epoch 00123: val_loss did not improve from 0.00073
# Epoch 124/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.8131e-05 - val_loss: 7.5985e-04
#
# Epoch 00124: val_loss did not improve from 0.00073
# Epoch 125/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.5179e-05 - val_loss: 7.1848e-04
#
# Epoch 00125: val_loss improved from 0.00073 to 0.00072, saving model to best_weights.h5
# Epoch 126/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.8159e-05 - val_loss: 7.5056e-04
#
# Epoch 00126: val_loss did not improve from 0.00072
# Epoch 127/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.7414e-05 - val_loss: 7.4520e-04
#
# Epoch 00127: val_loss did not improve from 0.00072
# Epoch 128/150
# 1712/1712 [==============================] - 18s 11ms/step - loss: 9.6170e-05 - val_loss: 7.7208e-04
#
# Epoch 00128: val_loss did not improve from 0.00072
# Epoch 129/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.4942e-05 - val_loss: 7.6938e-04
#
# Epoch 00129: val_loss did not improve from 0.00072
# Epoch 130/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.7848e-05 - val_loss: 7.3636e-04
#
# Epoch 00130: val_loss did not improve from 0.00072
# Epoch 131/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.4272e-05 - val_loss: 7.3665e-04
#
# Epoch 00131: val_loss did not improve from 0.00072
# Epoch 132/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.4558e-05 - val_loss: 7.4778e-04
#
# Epoch 00132: val_loss did not improve from 0.00072
# Epoch 133/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.3747e-05 - val_loss: 7.3463e-04
#
# Epoch 00133: val_loss did not improve from 0.00072
# Epoch 134/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.2855e-05 - val_loss: 7.3428e-04
#
# Epoch 00134: val_loss did not improve from 0.00072
# Epoch 135/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.4272e-05 - val_loss: 7.4801e-04
#
# Epoch 00135: val_loss did not improve from 0.00072
# Epoch 136/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.5727e-05 - val_loss: 7.6938e-04
#
# Epoch 00136: val_loss did not improve from 0.00072
# Epoch 137/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.3930e-05 - val_loss: 7.8246e-04
#
# Epoch 00137: val_loss did not improve from 0.00072
# Epoch 138/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.2306e-05 - val_loss: 7.3691e-04
#
# Epoch 00138: val_loss did not improve from 0.00072
# Epoch 139/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.2232e-05 - val_loss: 7.5503e-04
#
# Epoch 00139: val_loss did not improve from 0.00072
# Epoch 140/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.2277e-05 - val_loss: 7.4273e-04
#
# Epoch 00140: val_loss did not improve from 0.00072
# Epoch 141/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 8.9950e-05 - val_loss: 7.7092e-04
#
# Epoch 00141: val_loss did not improve from 0.00072
# Epoch 142/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 8.9713e-05 - val_loss: 7.7737e-04
#
# Epoch 00142: val_loss did not improve from 0.00072
# Epoch 143/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 8.9746e-05 - val_loss: 7.4335e-04
#
# Epoch 00143: val_loss did not improve from 0.00072
# Epoch 144/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.1187e-05 - val_loss: 7.7873e-04
#
# Epoch 00144: val_loss did not improve from 0.00072
# Epoch 145/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.3278e-05 - val_loss: 7.7324e-04
#
# Epoch 00145: val_loss did not improve from 0.00072
# Epoch 146/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.3488e-05 - val_loss: 7.4923e-04
#
# Epoch 00146: val_loss did not improve from 0.00072
# Epoch 147/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 8.7561e-05 - val_loss: 7.5922e-04
#
# Epoch 00147: val_loss did not improve from 0.00072
# Epoch 148/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 8.8712e-05 - val_loss: 7.4157e-04
#
# Epoch 00148: val_loss did not improve from 0.00072
# Epoch 149/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 8.6883e-05 - val_loss: 7.5346e-04
#
# Epoch 00149: val_loss did not improve from 0.00072
# Epoch 150/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 8.8523e-05 - val_loss: 7.8356e-04
#
# Epoch 00150: val_loss did not improve from 0.00072

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
# Your code

# 實現圖片以及關機點 label 做左右翻轉的函數
def augment_data(img, points):
    rows, cols = img.shape
    new_img = np.copy(img)
    new_img = np.fliplr(new_img)
            
    # 翻轉關鍵點 label
    new_points = np.copy(points)
    for i in range(0,30,2):
        new_points[i] = -points[i]
    
    # 調整對稱的 label
    new_points_temp = np.copy(new_points)
    new_points[0:2] = new_points_temp[2:4]
    new_points[2:4] = new_points_temp[0:2]
    new_points[4:6] = new_points_temp[8:10]
    new_points[6:8] = new_points_temp[10:12]
    new_points[8:10] = new_points_temp[4:6]
    new_points[10:12] = new_points_temp[6:8]
    new_points[12:14] = new_points_temp[16:18]
    new_points[14:16] = new_points_temp[18:20]
    new_points[16:18] = new_points_temp[12:14]
    new_points[18:20] = new_points_temp[14:16]
    new_points[22:24] = new_points_temp[24:26]
    new_points[24:26] = new_points_temp[22:24]
        
    return new_img, new_points

# %%
flip_img, flip_points = augment_data(imgs_train[0], points_train[0])

fig = plt.figure()
ax = fig.add_subplot(1, 2, 1, xticks=[], yticks=[])
plot_keypoints(imgs_train[0], points_train[0]) # 原來的圖片
ax = fig.add_subplot(1, 2, 2, xticks=[], yticks=[])
plot_keypoints(flip_img, flip_points) # 翻轉後的圖片

# %%
# 創建 list
aug_imgs_train = []
aug_points_train = []

# 對所有原始資料做 augmentation
for i in range(imgs_train.shape[0]):
    # 做左右翻轉
    aug_img, aug_point = augment_data(imgs_train[i], points_train[i])
    
    # append 原始資料
    aug_imgs_train.append(imgs_train[i])
    aug_points_train.append(points_train[i]) 
    
    # append 做過 augmentation 後的資料
    aug_imgs_train.append(aug_img)
    aug_points_train.append(aug_point) 

# convert to numpy
aug_imgs_train = np.array(aug_imgs_train)   
aug_points_train = np.copy(aug_points_train)

print(aug_imgs_train.shape)
print(aug_points_train.shape)
# Out:
# (4280, 96, 96)
# (4280, 30)

# %%
# model checkpoint 
checkpoint_aug = ModelCheckpoint('best_weights_augment.h5', verbose=1, save_best_only=True)
# training the model
hist_model_aug = model_with_augment.fit(aug_imgs_train.reshape(aug_imgs_train.shape[0], 96, 96, 1), aug_points_train, 
                           validation_split=0.2, batch_size=64, callbacks=[checkpoint_aug, hist],
                           shuffle=True, epochs=150, verbose=1)
# Out:
# Train on 3424 samples, validate on 856 samples
# Epoch 1/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 0.0056 - val_loss: 0.0020
#
# Epoch 00001: val_loss improved from inf to 0.00202, saving model to best_weights_augment.h5
# Epoch 2/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 0.0014 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00202 to 0.00193, saving model to best_weights_augment.h5
# Epoch 3/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 0.0012 - val_loss: 0.0019
#
# Epoch 00003: val_loss improved from 0.00193 to 0.00187, saving model to best_weights_augment.h5
# Epoch 4/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 0.0010 - val_loss: 0.0018
#
# Epoch 00004: val_loss improved from 0.00187 to 0.00183, saving model to best_weights_augment.h5
# Epoch 5/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.9111e-04 - val_loss: 0.0017
#
# Epoch 00005: val_loss improved from 0.00183 to 0.00166, saving model to best_weights_augment.h5
# Epoch 6/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 7.1347e-04 - val_loss: 0.0012
#
# Epoch 00006: val_loss improved from 0.00166 to 0.00124, saving model to best_weights_augment.h5
# Epoch 7/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 5.8494e-04 - val_loss: 0.0012
#
# Epoch 00007: val_loss improved from 0.00124 to 0.00115, saving model to best_weights_augment.h5
# Epoch 8/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 5.1624e-04 - val_loss: 0.0010
#
# Epoch 00008: val_loss improved from 0.00115 to 0.00101, saving model to best_weights_augment.h5
# Epoch 9/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 4.7219e-04 - val_loss: 9.5929e-04
#
# Epoch 00009: val_loss improved from 0.00101 to 0.00096, saving model to best_weights_augment.h5
# Epoch 10/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 4.3431e-04 - val_loss: 9.6566e-04
#
# Epoch 00010: val_loss did not improve from 0.00096
# Epoch 11/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 4.0471e-04 - val_loss: 8.8774e-04
#
# Epoch 00011: val_loss improved from 0.00096 to 0.00089, saving model to best_weights_augment.h5
# Epoch 12/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 3.8637e-04 - val_loss: 8.6188e-04
#
# Epoch 00012: val_loss improved from 0.00089 to 0.00086, saving model to best_weights_augment.h5
# Epoch 13/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 3.6239e-04 - val_loss: 7.9048e-04
#
# Epoch 00013: val_loss improved from 0.00086 to 0.00079, saving model to best_weights_augment.h5
# Epoch 14/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 3.4271e-04 - val_loss: 7.8359e-04
#
# Epoch 00014: val_loss improved from 0.00079 to 0.00078, saving model to best_weights_augment.h5
# Epoch 15/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 3.2844e-04 - val_loss: 7.4413e-04
#
# Epoch 00015: val_loss improved from 0.00078 to 0.00074, saving model to best_weights_augment.h5
# Epoch 16/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 3.1679e-04 - val_loss: 7.8941e-04
#
# Epoch 00016: val_loss did not improve from 0.00074
# Epoch 17/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 2.9993e-04 - val_loss: 7.5542e-04
#
# Epoch 00017: val_loss did not improve from 0.00074
# Epoch 18/150
# 3424/3424 [==============================] - 32s 9ms/step - loss: 2.9316e-04 - val_loss: 7.4760e-04
#
# Epoch 00018: val_loss did not improve from 0.00074
# Epoch 19/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 2.8691e-04 - val_loss: 7.5353e-04
#
# Epoch 00019: val_loss did not improve from 0.00074
# Epoch 20/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 2.8141e-04 - val_loss: 6.9571e-04
#
# Epoch 00020: val_loss improved from 0.00074 to 0.00070, saving model to best_weights_augment.h5
# Epoch 21/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 2.7403e-04 - val_loss: 7.2424e-04
#
# Epoch 00021: val_loss did not improve from 0.00070
# Epoch 22/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 2.6382e-04 - val_loss: 6.8022e-04
#
# Epoch 00022: val_loss improved from 0.00070 to 0.00068, saving model to best_weights_augment.h5
# Epoch 23/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 2.6015e-04 - val_loss: 6.6015e-04
#
# Epoch 00023: val_loss improved from 0.00068 to 0.00066, saving model to best_weights_augment.h5
# Epoch 24/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 2.4648e-04 - val_loss: 7.3454e-04
#
# Epoch 00024: val_loss did not improve from 0.00066
# Epoch 25/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 2.4317e-04 - val_loss: 6.7063e-04
#
# Epoch 00025: val_loss did not improve from 0.00066
# Epoch 26/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 2.3564e-04 - val_loss: 6.6297e-04
#
# Epoch 00026: val_loss did not improve from 0.00066
# Epoch 27/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 2.3190e-04 - val_loss: 6.5178e-04
#
# Epoch 00027: val_loss improved from 0.00066 to 0.00065, saving model to best_weights_augment.h5
# Epoch 28/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 2.2997e-04 - val_loss: 6.7955e-04
#
# Epoch 00028: val_loss did not improve from 0.00065
# Epoch 29/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 2.1827e-04 - val_loss: 6.9608e-04
#
# Epoch 00029: val_loss did not improve from 0.00065
# Epoch 30/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 2.2054e-04 - val_loss: 6.6576e-04
#
# Epoch 00030: val_loss did not improve from 0.00065
# Epoch 31/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 2.0806e-04 - val_loss: 6.5931e-04
#
# Epoch 00031: val_loss did not improve from 0.00065
# Epoch 32/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 2.0939e-04 - val_loss: 6.6810e-04
#
# Epoch 00032: val_loss did not improve from 0.00065
# Epoch 33/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 2.0250e-04 - val_loss: 6.7078e-04
#
# Epoch 00033: val_loss did not improve from 0.00065
# Epoch 34/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 2.0075e-04 - val_loss: 6.4591e-04
#
# Epoch 00034: val_loss improved from 0.00065 to 0.00065, saving model to best_weights_augment.h5
# Epoch 35/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.9364e-04 - val_loss: 6.4411e-04
#
# Epoch 00035: val_loss improved from 0.00065 to 0.00064, saving model to best_weights_augment.h5
# Epoch 36/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.9138e-04 - val_loss: 6.5142e-04
#
# Epoch 00036: val_loss did not improve from 0.00064
# Epoch 37/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.8819e-04 - val_loss: 6.5842e-04
#
# Epoch 00037: val_loss did not improve from 0.00064
# Epoch 38/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.8658e-04 - val_loss: 6.4465e-04
#
# Epoch 00038: val_loss did not improve from 0.00064
# Epoch 39/150
# 3424/3424 [==============================] - 31s 9ms/step - loss: 1.8048e-04 - val_loss: 6.6786e-04
#
# Epoch 00039: val_loss did not improve from 0.00064
# Epoch 40/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.8026e-04 - val_loss: 6.4411e-04
#
# Epoch 00040: val_loss improved from 0.00064 to 0.00064, saving model to best_weights_augment.h5
# Epoch 41/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.7528e-04 - val_loss: 6.5720e-04
#
# Epoch 00041: val_loss did not improve from 0.00064
# Epoch 42/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.7530e-04 - val_loss: 6.9290e-04
#
# Epoch 00042: val_loss did not improve from 0.00064
# Epoch 43/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.7180e-04 - val_loss: 6.7853e-04
#
# Epoch 00043: val_loss did not improve from 0.00064
# Epoch 44/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.7379e-04 - val_loss: 6.9180e-04
#
# Epoch 00044: val_loss did not improve from 0.00064
# Epoch 45/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.6465e-04 - val_loss: 6.3330e-04
#
# Epoch 00045: val_loss improved from 0.00064 to 0.00063, saving model to best_weights_augment.h5
# Epoch 46/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.6331e-04 - val_loss: 6.4625e-04
#
# Epoch 00046: val_loss did not improve from 0.00063
# Epoch 47/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.6232e-04 - val_loss: 6.3982e-04
#
# Epoch 00047: val_loss did not improve from 0.00063
# Epoch 48/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.5886e-04 - val_loss: 6.2062e-04
#
# Epoch 00048: val_loss improved from 0.00063 to 0.00062, saving model to best_weights_augment.h5
# Epoch 49/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.5369e-04 - val_loss: 6.5011e-04
#
# Epoch 00049: val_loss did not improve from 0.00062
# Epoch 50/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.5433e-04 - val_loss: 6.2392e-04
#
# Epoch 00050: val_loss did not improve from 0.00062
# Epoch 51/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.5231e-04 - val_loss: 6.4133e-04
#
# Epoch 00051: val_loss did not improve from 0.00062
# Epoch 52/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.4812e-04 - val_loss: 6.3486e-04
#
# Epoch 00052: val_loss did not improve from 0.00062
# Epoch 53/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.4919e-04 - val_loss: 6.6066e-04
#
# Epoch 00053: val_loss did not improve from 0.00062
# Epoch 54/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.4792e-04 - val_loss: 6.5836e-04
#
# Epoch 00054: val_loss did not improve from 0.00062
# Epoch 55/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.4361e-04 - val_loss: 6.4738e-04
#
# Epoch 00055: val_loss did not improve from 0.00062
# Epoch 56/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.4496e-04 - val_loss: 6.7409e-04
#
# Epoch 00056: val_loss did not improve from 0.00062
# Epoch 57/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.4384e-04 - val_loss: 6.6950e-04
#
# Epoch 00057: val_loss did not improve from 0.00062
# Epoch 58/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.4630e-04 - val_loss: 6.3585e-04
#
# Epoch 00058: val_loss did not improve from 0.00062
# Epoch 59/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.3740e-04 - val_loss: 6.3841e-04
#
# Epoch 00059: val_loss did not improve from 0.00062
# Epoch 60/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.3830e-04 - val_loss: 6.2771e-04
#
# Epoch 00060: val_loss did not improve from 0.00062
# Epoch 61/150
# 3424/3424 [==============================] - 31s 9ms/step - loss: 1.3592e-04 - val_loss: 6.3881e-04
#
# Epoch 00061: val_loss did not improve from 0.00062
# Epoch 62/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.3602e-04 - val_loss: 6.7074e-04
#
# Epoch 00062: val_loss did not improve from 0.00062
# Epoch 63/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.3321e-04 - val_loss: 6.2832e-04
#
# Epoch 00063: val_loss did not improve from 0.00062
# Epoch 64/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.2764e-04 - val_loss: 6.5660e-04
#
# Epoch 00064: val_loss did not improve from 0.00062
# Epoch 65/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.3035e-04 - val_loss: 6.5654e-04
#
# Epoch 00065: val_loss did not improve from 0.00062
# Epoch 66/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.2766e-04 - val_loss: 6.3541e-04
#
# Epoch 00066: val_loss did not improve from 0.00062
# Epoch 67/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.2962e-04 - val_loss: 6.4267e-04
#
# Epoch 00067: val_loss did not improve from 0.00062
# Epoch 68/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.2682e-04 - val_loss: 6.3735e-04
#
# Epoch 00068: val_loss did not improve from 0.00062
# Epoch 69/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.2606e-04 - val_loss: 6.3432e-04
#
# Epoch 00069: val_loss did not improve from 0.00062
# Epoch 70/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.2549e-04 - val_loss: 6.1384e-04
#
# Epoch 00070: val_loss improved from 0.00062 to 0.00061, saving model to best_weights_augment.h5
# Epoch 71/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.2248e-04 - val_loss: 6.3613e-04
#
# Epoch 00071: val_loss did not improve from 0.00061
# Epoch 72/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.2076e-04 - val_loss: 6.7522e-04
#
# Epoch 00072: val_loss did not improve from 0.00061
# Epoch 73/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.1945e-04 - val_loss: 6.2461e-04
#
# Epoch 00073: val_loss did not improve from 0.00061
# Epoch 74/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.2010e-04 - val_loss: 6.3415e-04
#
# Epoch 00074: val_loss did not improve from 0.00061
# Epoch 75/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.1937e-04 - val_loss: 6.1237e-04
#
# Epoch 00075: val_loss improved from 0.00061 to 0.00061, saving model to best_weights_augment.h5
# Epoch 76/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.1693e-04 - val_loss: 6.4521e-04
#
# Epoch 00076: val_loss did not improve from 0.00061
# Epoch 77/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.1499e-04 - val_loss: 6.4386e-04
#
# Epoch 00077: val_loss did not improve from 0.00061
# Epoch 78/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.1481e-04 - val_loss: 6.5143e-04
#
# Epoch 00078: val_loss did not improve from 0.00061
# Epoch 79/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.1429e-04 - val_loss: 6.5682e-04
#
# Epoch 00079: val_loss did not improve from 0.00061
# Epoch 80/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.1342e-04 - val_loss: 6.2806e-04
#
# Epoch 00080: val_loss did not improve from 0.00061
# Epoch 81/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.1125e-04 - val_loss: 6.6109e-04
#
# Epoch 00081: val_loss did not improve from 0.00061
# Epoch 82/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.1254e-04 - val_loss: 6.7969e-04
#
# Epoch 00082: val_loss did not improve from 0.00061
# Epoch 83/150
# 3424/3424 [==============================] - 31s 9ms/step - loss: 1.0935e-04 - val_loss: 6.3334e-04
#
# Epoch 00083: val_loss did not improve from 0.00061
# Epoch 84/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.1199e-04 - val_loss: 6.4098e-04
#
# Epoch 00084: val_loss did not improve from 0.00061
# Epoch 85/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.1090e-04 - val_loss: 6.2115e-04
#
# Epoch 00085: val_loss did not improve from 0.00061
# Epoch 86/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.0834e-04 - val_loss: 6.6573e-04
#
# Epoch 00086: val_loss did not improve from 0.00061
# Epoch 87/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.0799e-04 - val_loss: 6.5017e-04
#
# Epoch 00087: val_loss did not improve from 0.00061
# Epoch 88/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.1034e-04 - val_loss: 6.3109e-04
#
# Epoch 00088: val_loss did not improve from 0.00061
# Epoch 89/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.0621e-04 - val_loss: 6.1710e-04
#
# Epoch 00089: val_loss did not improve from 0.00061
# Epoch 90/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.0728e-04 - val_loss: 6.1383e-04
#
# Epoch 00090: val_loss did not improve from 0.00061
# Epoch 91/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.0576e-04 - val_loss: 6.5869e-04
#
# Epoch 00091: val_loss did not improve from 0.00061
# Epoch 92/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.0129e-04 - val_loss: 6.2183e-04
#
# Epoch 00092: val_loss did not improve from 0.00061
# Epoch 93/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.0434e-04 - val_loss: 6.2692e-04
#
# Epoch 00093: val_loss did not improve from 0.00061
# Epoch 94/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.0462e-04 - val_loss: 6.1482e-04
#
# Epoch 00094: val_loss did not improve from 0.00061
# Epoch 95/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.0090e-04 - val_loss: 6.3728e-04
#
# Epoch 00095: val_loss did not improve from 0.00061
# Epoch 96/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.0163e-04 - val_loss: 6.1375e-04
#
# Epoch 00096: val_loss did not improve from 0.00061
# Epoch 97/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.0041e-04 - val_loss: 6.2654e-04
#
# Epoch 00097: val_loss did not improve from 0.00061
# Epoch 98/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.0017e-04 - val_loss: 6.4359e-04
#
# Epoch 00098: val_loss did not improve from 0.00061
# Epoch 99/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.0254e-04 - val_loss: 6.3063e-04
#
# Epoch 00099: val_loss did not improve from 0.00061
# Epoch 100/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.9842e-05 - val_loss: 6.4056e-04
#
# Epoch 00100: val_loss did not improve from 0.00061
# Epoch 101/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.8313e-05 - val_loss: 6.2531e-04
#
# Epoch 00101: val_loss did not improve from 0.00061
# Epoch 102/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.8399e-05 - val_loss: 6.1558e-04
#
# Epoch 00102: val_loss did not improve from 0.00061
# Epoch 103/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.7032e-05 - val_loss: 6.2437e-04
#
# Epoch 00103: val_loss did not improve from 0.00061
# Epoch 104/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.6870e-05 - val_loss: 6.1683e-04
#
# Epoch 00104: val_loss did not improve from 0.00061
# Epoch 105/150
# 3424/3424 [==============================] - 32s 9ms/step - loss: 9.8505e-05 - val_loss: 6.4662e-04
#
# Epoch 00105: val_loss did not improve from 0.00061
# Epoch 106/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.9124e-05 - val_loss: 6.1651e-04
#
# Epoch 00106: val_loss did not improve from 0.00061
# Epoch 107/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.9923e-05 - val_loss: 6.3482e-04
#
# Epoch 00107: val_loss did not improve from 0.00061
# Epoch 108/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.7710e-05 - val_loss: 6.4118e-04
#
# Epoch 00108: val_loss did not improve from 0.00061
# Epoch 109/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.7234e-05 - val_loss: 6.5323e-04
#
# Epoch 00109: val_loss did not improve from 0.00061
# Epoch 110/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.5416e-05 - val_loss: 6.4290e-04
#
# Epoch 00110: val_loss did not improve from 0.00061
# Epoch 111/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.4151e-05 - val_loss: 6.3094e-04
#
# Epoch 00111: val_loss did not improve from 0.00061
# Epoch 112/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.4623e-05 - val_loss: 6.1226e-04
#
# Epoch 00112: val_loss improved from 0.00061 to 0.00061, saving model to best_weights_augment.h5
# Epoch 113/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.3752e-05 - val_loss: 6.4550e-04
#
# Epoch 00113: val_loss did not improve from 0.00061
# Epoch 114/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 9.2532e-05 - val_loss: 6.5713e-04
#
# Epoch 00114: val_loss did not improve from 0.00061
# Epoch 115/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 9.1280e-05 - val_loss: 6.2295e-04
#
# Epoch 00115: val_loss did not improve from 0.00061
# Epoch 116/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.1623e-05 - val_loss: 6.1488e-04
#
# Epoch 00116: val_loss did not improve from 0.00061
# Epoch 117/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.3101e-05 - val_loss: 6.4998e-04
#
# Epoch 00117: val_loss did not improve from 0.00061
# Epoch 118/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.2977e-05 - val_loss: 6.3565e-04
#
# Epoch 00118: val_loss did not improve from 0.00061
# Epoch 119/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.4322e-05 - val_loss: 6.3669e-04
#
# Epoch 00119: val_loss did not improve from 0.00061
# Epoch 120/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.6142e-05 - val_loss: 6.3238e-04
#
# Epoch 00120: val_loss did not improve from 0.00061
# Epoch 121/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.4176e-05 - val_loss: 6.2731e-04
#
# Epoch 00121: val_loss did not improve from 0.00061
# Epoch 122/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.2625e-05 - val_loss: 6.6586e-04
#
# Epoch 00122: val_loss did not improve from 0.00061
# Epoch 123/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.5604e-05 - val_loss: 6.3570e-04
#
# Epoch 00123: val_loss did not improve from 0.00061
# Epoch 124/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.1947e-05 - val_loss: 6.3403e-04
#
# Epoch 00124: val_loss did not improve from 0.00061
# Epoch 125/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.1092e-05 - val_loss: 6.3677e-04
#
# Epoch 00125: val_loss did not improve from 0.00061
# Epoch 126/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.0184e-05 - val_loss: 6.3971e-04
#
# Epoch 00126: val_loss did not improve from 0.00061
# Epoch 127/150
# 3424/3424 [==============================] - 33s 10ms/step - loss: 8.7513e-05 - val_loss: 6.3782e-04
#
# Epoch 00127: val_loss did not improve from 0.00061
# Epoch 128/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.6913e-05 - val_loss: 6.2958e-04
#
# Epoch 00128: val_loss did not improve from 0.00061
# Epoch 129/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.0366e-05 - val_loss: 6.2966e-04
#
# Epoch 00129: val_loss did not improve from 0.00061
# Epoch 130/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.8430e-05 - val_loss: 6.2551e-04
#
# Epoch 00130: val_loss did not improve from 0.00061
# Epoch 131/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.0495e-05 - val_loss: 6.3631e-04
#
# Epoch 00131: val_loss did not improve from 0.00061
# Epoch 132/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.9432e-05 - val_loss: 6.3875e-04
#
# Epoch 00132: val_loss did not improve from 0.00061
# Epoch 133/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.9122e-05 - val_loss: 6.2357e-04
#
# Epoch 00133: val_loss did not improve from 0.00061
# Epoch 134/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.8110e-05 - val_loss: 6.2839e-04
#
# Epoch 00134: val_loss did not improve from 0.00061
# Epoch 135/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.9161e-05 - val_loss: 6.3554e-04
#
# Epoch 00135: val_loss did not improve from 0.00061
# Epoch 136/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.8055e-05 - val_loss: 6.2445e-04
#
# Epoch 00136: val_loss did not improve from 0.00061
# Epoch 137/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.6841e-05 - val_loss: 6.5351e-04
#
# Epoch 00137: val_loss did not improve from 0.00061
# Epoch 138/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.7340e-05 - val_loss: 6.5009e-04
#
# Epoch 00138: val_loss did not improve from 0.00061
# Epoch 139/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.5505e-05 - val_loss: 6.4507e-04
#
# Epoch 00139: val_loss did not improve from 0.00061
# Epoch 140/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.6955e-05 - val_loss: 6.3267e-04
#
# Epoch 00140: val_loss did not improve from 0.00061
# Epoch 141/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.9175e-05 - val_loss: 6.3942e-04
#
# Epoch 00141: val_loss did not improve from 0.00061
# Epoch 142/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.7385e-05 - val_loss: 6.4679e-04
#
# Epoch 00142: val_loss did not improve from 0.00061
# Epoch 143/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.7111e-05 - val_loss: 6.3865e-04
#
# Epoch 00143: val_loss did not improve from 0.00061
# Epoch 144/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.8087e-05 - val_loss: 6.3451e-04
#
# Epoch 00144: val_loss did not improve from 0.00061
# Epoch 145/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.3745e-05 - val_loss: 6.1992e-04
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.5384e-05 - val_loss: 6.2695e-04
#
# Epoch 00146: val_loss did not improve from 0.00061
# Epoch 147/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.3495e-05 - val_loss: 6.2991e-04
#
# Epoch 00147: val_loss did not improve from 0.00061
# Epoch 148/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.3104e-05 - val_loss: 6.4750e-04
#
# Epoch 00148: val_loss did not improve from 0.00061
# Epoch 149/150
# 3424/3424 [==============================] - 31s 9ms/step - loss: 8.3384e-05 - val_loss: 6.3144e-04
#
# Epoch 00149: val_loss did not improve from 0.00061
# Epoch 150/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.6410e-05 - val_loss: 6.0838e-04
#
# Epoch 00150: val_loss improved from 0.00061 to 0.00061, saving model to best_weights_augment.h5

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model_aug.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model_aug.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')
